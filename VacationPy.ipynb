# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import holoviews as hv
import pandas as pd
import requests
import warnings

# Import API key
# from api_keys import geoapify_key
from dotenv import load_dotenv
import os

load_dotenv()
geoapify_key = os.getenv("GEOAPIFY_KEY")

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat      Lng  Max Temp  Humidity  \
# 0        0                      dudinka  69.4058  86.1778     48.34        64
# 1        1                       uribia  11.7139 -72.2660     94.08        44
# 2        2                     tazovsky  67.4667  78.7000     48.61        65
# 3        3  edinburgh of the seven seas -37.0676 -12.3116     57.00        87
# 4        4                  otjiwarongo -20.4637  16.6477     67.73        20
#
#    Cloudiness  Wind Speed Country        Date
# 0           1        8.38      RU  1722876385
# 1          85        8.17      CO  1722876974
# 2          96        5.97      RU  1722876457
# 3          64       13.18      SH  1722876976
# 4           0        0.69     NaN  1722876977

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    x="Lng",
    y="Lat",
    geo=True,
    tiles="OSM",
    title="City Locations",
    hover_cols=["City", "Country"],
    frame_width=700,
    frame_height=500,
    color = "City" ,
    cmap = "Category10",
    alpha = 0.5
)

# Save the plot to an HTML file
hv.save(map_plot,"output_data/map_plot.html")

# Display the map
map_plot
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p2408', ...)
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# A max temperature lower than 90 degrees but higher than 65.
# Wind speed less than 10 mph.
# Cloudiness less than 50.
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
ideal_weather_df = city_data_df.loc[
    (city_data_df["Max Temp"] < 90)
    & (city_data_df["Max Temp"] > 65)
    & (city_data_df["Wind Speed"] < 10)
    & (city_data_df["Cloudiness"] == 0)
]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
ideal_weather_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 6          6               misratah  32.3754   15.0925     86.72        53
# 16        16                   lata  40.1629   -8.3327     83.48        47
# 18        18                  lihue  21.9789 -159.3672     76.24        82
# 42        42                 saipan  15.1355  145.7010     81.30        89
# 52        52              morondava -20.2833   44.2833     72.57        72
# 59        59                   alta  69.9689   23.2717     76.26        38
# 68        68      wailua homesteads  22.0669 -159.3780     75.63        81
# 76        76               la passe  45.5549   -0.8967     88.03        60
# 87        87                 beidao  34.5686  105.8933     71.13        88
# 93        93             pantelimon  44.4500   26.2000     84.36        38
# 100      100                conchal -22.3303  -47.1725     86.16        23
# 123      123             hammerfest  70.6634   23.6821     73.85        43
# 154      154                  kursk  51.7303   36.1939     71.80        65
# 161      161                farkhar  36.5729   69.8578     74.32        27
# 178      178                 luanda  -8.8368   13.2343     71.60        78
# 180      180              mariehamn  60.0973   19.9348     67.86        73
# 187      187        arraial do cabo -22.9661  -42.0278     84.16        54
# 205      205                  pecos  31.4229 -103.4932     86.09        42
# 215      215                 tukrah  32.5341   20.5791     85.41        59
# 228      228          itau de minas -20.7394  -46.7522     84.67        26
# 233      233          cockburn town  21.4612  -71.1419     82.87        83
# 250      250  truth or consequences  33.1284 -107.2528     88.03        37
# 257      257           mersa matruh  31.3525   27.2453     84.40        79
# 265      265                 bethel  41.3712  -73.4140     88.41        60
# 272      272               karratha -20.7377  116.8463     65.91        36
# 298      298                mashhad  36.2970   59.6062     84.34        32
# 332      332               tolanaro -25.0319   46.9987     71.67        83
# 372      372                 tarija -21.5355  -64.7296     75.11        35
# 398      398                 ghanzi -21.5667   21.7833     65.05        21
# 400      400                  karoi -16.8099   29.6925     66.88        16
# 405      405                 yafran  32.0633   12.5286     83.30        64
# 406      406                 laguna  38.4210 -121.4238     87.08        53
    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")


# Display sample data
hotel_df
# Out:
# Starting hotel search
# misratah - nearest hotel: الفندق السياحى
# lata - nearest hotel: No hotel found
# lihue - nearest hotel: Kauai Palms
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# morondava - nearest hotel: Hotel Sharon Menabe
# alta - nearest hotel: Scandic Alta
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# la passe - nearest hotel: L'Estuaire
# beidao - nearest hotel: 麦积大酒店
# pantelimon - nearest hotel: Hotel Lebăda
# conchal - nearest hotel: No hotel found
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# kursk - nearest hotel: Центральная
# farkhar - nearest hotel: No hotel found
# luanda - nearest hotel: Hotel Forum
# mariehamn - nearest hotel: Hotell Esplanad
# arraial do cabo - nearest hotel: No hotel found
# pecos - nearest hotel: Holiday Inn Express & Suites Pecos
# tukrah - nearest hotel: No hotel found
# itau de minas - nearest hotel: No hotel found
# cockburn town - nearest hotel: The Salt Raker Inn
# truth or consequences - nearest hotel: Travelodge
# mersa matruh - nearest hotel: صقور
# bethel - nearest hotel: Hampton Inn Danbury
# karratha - nearest hotel: Karratha International Hotel
# mashhad - nearest hotel: هتل تعاون
# tolanaro - nearest hotel: Hôtel Mahavokey
# tarija - nearest hotel: Hostal Bolivar
# ghanzi - nearest hotel: Ghanzi farmhouse
# karoi - nearest hotel: The Champion Lodge
# yafran - nearest hotel: فندق يفرن السياحي
# laguna - nearest hotel: Holiday Inn Express & Suites
# newman - nearest hotel: No hotel found
# vernon - nearest hotel: Okanagan Royal Park Inn
# big spring - nearest hotel: Settles Hotel
# havre - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: No hotel found
# jumelles - nearest hotel: No hotel found
# ulanhot - nearest hotel: 阿勒泰大酒店
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# prado - nearest hotel: Pousada Recanto do Prado
# kailua-kona - nearest hotel: Kona Seaside Hotel
# fenghua - nearest hotel: 亚朵酒店
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# saint-pierre - nearest hotel: Tropic Hotel
# bozeman - nearest hotel: Kimpton Armory Hotel Bozeman
# tataouine - nearest hotel: No hotel found
# kristiansund - nearest hotel: Comfort Hotel Fosna
#                       City Country      Lat       Lng  Humidity  \
# 6                 misratah      LY  32.3754   15.0925        53
# 16                    lata      PT  40.1629   -8.3327        47
# 18                   lihue      US  21.9789 -159.3672        82
# 42                  saipan      MP  15.1355  145.7010        89
# 52               morondava      MG -20.2833   44.2833        72
# 59                    alta      NO  69.9689   23.2717        38
# 68       wailua homesteads      US  22.0669 -159.3780        81
# 76                la passe      FR  45.5549   -0.8967        60
# 87                  beidao      CN  34.5686  105.8933        88
# 93              pantelimon      RO  44.4500   26.2000        38
# 100                conchal      BR -22.3303  -47.1725        23
# 123             hammerfest      NO  70.6634   23.6821        43
# 154                  kursk      RU  51.7303   36.1939        65
# 161                farkhar      AF  36.5729   69.8578        27
# 178                 luanda      AO  -8.8368   13.2343        78
# 180              mariehamn      AX  60.0973   19.9348        73
# 187        arraial do cabo      BR -22.9661  -42.0278        54
# 205                  pecos      US  31.4229 -103.4932        42
# 215                 tukrah      LY  32.5341   20.5791        59
# 228          itau de minas      BR -20.7394  -46.7522        26
# 233          cockburn town      TC  21.4612  -71.1419        83
# 250  truth or consequences      US  33.1284 -107.2528        37
# 257           mersa matruh      EG  31.3525   27.2453        79
# 265                 bethel      US  41.3712  -73.4140        60
# 272               karratha      AU -20.7377  116.8463        36
# 298                mashhad      IR  36.2970   59.6062        32
# 332               tolanaro      MG -25.0319   46.9987        83
# 372                 tarija      BO -21.5355  -64.7296        35
# 398                 ghanzi      BW -21.5667   21.7833        21
# 400                  karoi      ZW -16.8099   29.6925        16
# 405                 yafran      LY  32.0633   12.5286        64
# 406                 laguna      US  38.4210 -121.4238        53
# 410                 newman      US  37.3138 -121.0208        23
# 420                 vernon      CA  50.2581 -119.2691        51
# 422             big spring      US  32.2504 -101.4787        48
# 443                  havre      FR  49.5833    0.3333        68
# 464          haiku-pauwela      US  20.9219 -156.3051        81
# 470               jumelles      FR  47.4351   -0.1037        52
# 471                ulanhot      CN  46.0833  122.0833        71
# 473      sao joao da barra      BR -21.6403  -41.0511        76
# 493                  prado      BR -17.3411  -39.2208        64
# 502            kailua-kona      US  19.6406 -155.9956        90
# 503                fenghua      CN  29.6563  121.4064        74
# 516                 tromso      NO  69.6496   18.9570        46
# 561           saint-pierre      RE -21.3393   55.4781        73
# 564                bozeman      US  45.6796 -111.0386        55
# 566              tataouine      TN  32.9297   10.4518        27
# 572           kristiansund      NO  63.1115    7.7320        87
#
#                              Hotel Name
# 6                        الفندق السياحى
# 16                       No hotel found
# 18                          Kauai Palms
# 42             Chalan Kanoa Beach Hotel
# 52                  Hotel Sharon Menabe
# 59                         Scandic Alta
# 68   Hilton Garden Inn Kauai Wailua Bay
# 76                           L'Estuaire
# 87                                麦积大酒店
# 93                         Hotel Lebăda
# 100                      No hotel found
# 123               Thon Hotel Hammerfest
# 154                         Центральная
# 161                      No hotel found
# 178                         Hotel Forum
# 180                     Hotell Esplanad
# 187                      No hotel found
# 205  Holiday Inn Express & Suites Pecos
# 215                      No hotel found
# 228                      No hotel found
# 233                  The Salt Raker Inn
# 250                          Travelodge
# 257                                صقور
# 265                 Hampton Inn Danbury
# 272        Karratha International Hotel
# 298                           هتل تعاون
# 332                     Hôtel Mahavokey
# 372                      Hostal Bolivar
# 398                    Ghanzi farmhouse
# 400                  The Champion Lodge
# 405                   فندق يفرن السياحي
# 406        Holiday Inn Express & Suites
# 410                      No hotel found
# 420             Okanagan Royal Park Inn
# 422                       Settles Hotel
# 443                      No hotel found
# 464                      No hotel found
# 470                      No hotel found
# 471                              阿勒泰大酒店
# 473                Pousada Mediterrâneo
# 493            Pousada Recanto do Prado
# 502                  Kona Seaside Hotel
# 503                                亚朵酒店
# 516     Clarion Collection Hotel Aurora
# 561                        Tropic Hotel
# 564        Kimpton Armory Hotel Bozeman
# 566                      No hotel found
# 572                 Comfort Hotel Fosna

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map_plot = hotel_df.hvplot.points(
    x="Lng",
    y="Lat",
    geo=True,
    tiles="OSM",
    title="Hotel Locations",
    hover_cols=["Hotel Name", "City", "Country"],
    frame_width=700,
    frame_height=500,
    color = "City" ,
    cmap = "Category10",
    alpha = 0.5
)

# Save the map plot to an HTML file
hv.save(hotel_map_plot,"output_data/hotel_map_plot.html")
# Display the map
hotel_map_plot
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p2620', ...)
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
